# %%
import pandas as pd
from sklearn import svm

# %%
# read data from csv
def read_data():
    train = pd.read_csv('../input/train_features')
    test = pd.read_csv('../input/test_features')
    label = pd.read_csv('../input/train_label',header=None)
    return train,test,label

# %%
clf = svm.LinearSVR(dual=False)

# %%
X_train,X_test,y = read_data()

# %%
X_train
# Out:
#       MSSubClass  LotFrontage    LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       4.110874     4.189655   9.042040            7            5       2003
# 1       3.044522     4.394449   9.169623            6            8       1976
# 2       4.110874     4.234107   9.328212            7            5       2001
# 3       4.262680     4.110874   9.164401            7            5       1915
# 4       4.110874     4.442651   9.565284            8            5       2000
# 5       3.931826     4.454347   9.555064            5            5       1993
# 6       3.044522     4.330733   9.218804            8            5       2004
# 7       4.110874     4.196175   9.247925            7            6       1973
# 8       3.931826     3.951244   8.719481            7            5       1931
# 9       5.252273     3.931826   8.912069            5            6       1939
# 10      3.044522     4.262680   9.323758            5            5       1965
# ...

# %%
cro_train, cro_test, cro_y_train, cor_y_test = train_test_split(X_train, y, test_size=0.4, random_state=0)

# %%
from sklearn.model_selection import train_test_split

# %%
cro_train
# Out:
#       MSSubClass  LotFrontage    LotArea  OverallQual  OverallCond  YearBuilt  \
# 1169    4.110874     4.779123  10.484613           10            5       1995
# 1146    3.044522     4.196175   9.323758            6            5       1985
# 503     3.044522     4.615121   9.655218            7            8       1959
# 1449    5.198497     3.091042   7.335634            5            7       1970
# 1063    3.433987     3.931826   8.699681            6            6       1925
# 711     3.931826     4.204693   9.072571            4            7       1900
# 801     3.433987     3.713572   8.476580            4            7       1916
# 864     3.044522     4.290459   9.064274            7            5       2007
# 367     4.394449     4.624973   9.121618            6            5       1962
# 1444    3.044522     4.158883   9.047939            7            5       2004
# 384     4.110874     4.196175  10.880083            6            5       1992
# ...

# %%
clf.fit(cro_train,cro_y_train)
# Out:
# /usr/local/lib/python2.7/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ecc60a55571a> in <module>()
# ----> 1 clf.fit(cro_train,cro_y_train)
#
# /usr/local/lib/python2.7/site-packages/sklearn/svm/classes.pyc in fit(self, X, y, sample_weight)
#     379             None, penalty, self.dual, self.verbose,
#     380             self.max_iter, self.tol, self.random_state, loss=self.loss,
# --> 381             epsilon=self.epsilon, sample_weight=sample_weight)
#     382         self.coef_ = self.coef_.ravel()
#     383
#
# ...

# %%
type(cro_y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np

# %%
cro_y_train=np.matrix(cro_y_train)

# %%
clf.fit(cro_train,cro_y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ecc60a55571a> in <module>()
# ----> 1 clf.fit(cro_train,cro_y_train)
#
# /usr/local/lib/python2.7/site-packages/sklearn/svm/classes.pyc in fit(self, X, y, sample_weight)
#     379             None, penalty, self.dual, self.verbose,
#     380             self.max_iter, self.tol, self.random_state, loss=self.loss,
# --> 381             epsilon=self.epsilon, sample_weight=sample_weight)
#     382         self.coef_ = self.coef_.ravel()
#     383
#
# /usr/local/lib/python2.7/site-packages/sklearn/svm/base.pyc in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     906         check_consistent_length(sample_weight, X)
#     907
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d5d696ea8fd8> in <module>()
# ----> 1 clf.fit(X_train,y)
#
# /usr/local/lib/python2.7/site-packages/sklearn/svm/classes.pyc in fit(self, X, y, sample_weight)
#     379             None, penalty, self.dual, self.verbose,
#     380             self.max_iter, self.tol, self.random_state, loss=self.loss,
# --> 381             epsilon=self.epsilon, sample_weight=sample_weight)
#     382         self.coef_ = self.coef_.ravel()
#     383
#
# /usr/local/lib/python2.7/site-packages/sklearn/svm/base.pyc in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     906         check_consistent_length(sample_weight, X)
#     907
# ...

# %%
clf = svm.LinearSVR()

# %%
clf.fit(cro_train,cro_y_train)
# Out:
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#      intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#      random_state=None, tol=0.0001, verbose=0)

# %%
clf.score(cro_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-4fb692dacbb9> in <module>()
# ----> 1 clf.score(cro_test)
#
# TypeError: score() takes at least 3 arguments (2 given)

# %%
pre_value= clf.predict(cro_test)

# %%
rmse = (pre_value-np.array(cor_y_test))

# %%
type(pre_value)
# Out:
# numpy.ndarray

# %%
type(np.array(cor_y_test))
# Out:
# numpy.ndarray

# %%
rmse
# Out:
# array([[-0.10107771, -0.41736935, -0.32777675, ..., -0.18282344,
#          0.10964282,  0.26440444],
#        [ 0.31000314, -0.0062885 ,  0.0833041 , ...,  0.22825741,
#          0.52072367,  0.67548528],
#        [ 0.49987033,  0.18357869,  0.27317129, ...,  0.4181246 ,
#          0.71059086,  0.86535247],
#        ...,
#        [ 0.28110175, -0.03518989,  0.05440271, ...,  0.19935602,
#          0.49182228,  0.64658389],
#        [-0.04139252, -0.35768416, -0.26809156, ..., -0.12313825,
#          0.16932801,  0.32408962],
#        [-0.21530052, -0.53159216, -0.44199956, ..., -0.29704625,
#         -0.00457999,  0.15018163]])

# %%
rmse^rmse
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-0c14c299fd36> in <module>()
# ----> 1 rmse^rmse
#
# TypeError: ufunc 'bitwise_xor' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
pf_rmse=np.square(rmse)

# %%
np.sum(pf_rmse)
# Out:
# 95100.336232689937

# %%
pf_rmse.sum()
# Out:
# 95100.336232689937

# %%
pf_rmse.shape
# Out:
# (584, 584)

# %%
rmse.shape
# Out:
# (584, 584)
